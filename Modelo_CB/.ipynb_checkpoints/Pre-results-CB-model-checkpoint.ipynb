# %%
#pip install -U sentence-transformers

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.porter import PorterStemmer
from sqlalchemy import create_engine
import pandas as pd
import re
import gensim.corpora as corpora
from pprint import pprint
import contractions
import demoji
import string

import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize

from gensim.corpora.dictionary import Dictionary

from gensim.similarities import Similarity

from gensim.test.utils import get_tmpfile

from gensim.models import CoherenceModel

from sentence_transformers import SentenceTransformer, util

import matplotlib.pyplot as plt

import numpy as np

import math

import csv
from tqdm import tqdm
# Out:
# [nltk_data] Downloading package punkt to /home/profesor/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def getSqlResult(sql):
    db_connection_str = 'mysql+pymysql://profesor:Tesis_2022@localhost/info_coursesdb'
    db_connection = create_engine(db_connection_str)
    return pd.read_sql(sql, con=db_connection)

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        # deacc=True removes punctuations
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))
        

def preprocess_text(text_col):
    
    # convert to lowercase
    text_col = text_col.apply(lambda x: ' '.join([w.lower() for w in x.split()]))
    
    # remove emojis
    text_col = text_col.apply(lambda x: demoji.replace(x, ""))
    
    # expand contractions  
    text_col = text_col.apply(lambda x: ' '.join([contractions.fix(word) for word in x.split()]))

    # remove punctuation
    text_col = text_col.apply(lambda x: ''.join([i for i in x if i not in string.punctuation]))
    
    # remove numbers
    text_col = text_col.apply(lambda x: ' '.join(re.sub("[^a-zA-Z]+", " ", x).split()))
    
    #Stop words
    text_col = text_col.apply(lambda x: gensim.parsing.preprocessing.remove_stopwords(x))
    
    #Stem text
    text_col = text_col.apply(lambda x: gensim.parsing.preprocessing.stem_text(x))
    
    #Tokenizer
    text_col = text_col.apply(lambda x: word_tokenize(x))
    
    return text_col
    
def get_corpus(data_words):
    id2word = corpora.Dictionary(data_words)
    corpus = [id2word.doc2bow(text) for text in data_words]

def generate_model(common_corpus, num_topics, passes):
    return gensim.models.LdaMulticore(common_corpus, 
                                      num_topics=num_topics, 
                                      id2word=common_dictionary,
                                      passes=passes,
                                      minimum_probability = 0,
                                      random_state = 1)


def generate_sr_model_transformer(full_sentences, transformer_name, df_test, df_train, df_courses):
    model = SentenceTransformer(transformer_name)
    embeddings = model.encode(full_sentences)
    embeddings_tuple = [list(zip(range(0,len(embeddings[0])),vector)) for vector in embeddings]
    recommendations = recommended_by_course(embeddings_tuple,len(embeddings_tuple[0]), df_train, df_courses)
    final_array , len_courses = binary_array_recommendations(recommendations, df_test, df_courses)
    metric = custom_mean_precision(final_array , len_courses)
    print("custom ",metric)
    

def evaluate_model(model, corpus):
    # Compute Perplexity (lower is better)
    print('Perplexity: ', round(model.log_perplexity(corpus), 2))

    # Compute Coherence Score (higher is better)
    coherence_model_lda = CoherenceModel(model=model, texts=df["tokens"], dictionary=common_dictionary, coherence='c_v')
    coherence_lda = coherence_model_lda.get_coherence()
    print('Coherence Score: ', round(coherence_lda, 2))
    return round(model.log_perplexity(corpus), 2), round(coherence_lda, 2)
    
def plot_results(perplexity,coherence,numbers_topics):
    fig, ax1 = plt.subplots()
    ax2 = ax1.twinx()
    ax1.plot(numbers_topics, perplexity, 'g-')
    ax2.plot(numbers_topics, coherence, 'b-')
    ax1.set_xlabel('Number topics')
    ax1.set_ylabel('perplexity', color='g')
    ax2.set_ylabel('coherence', color='b')
    plt.show()

def plot_results_topics(metric,numbers_topics):
    fig, ax1 = plt.subplots()
    ax1.plot(numbers_topics, metric)
    ax1.set_xlabel('Number topics')
    ax1.set_ylabel('Precisión')
    plt.show()
    
def find_best_topic(corpus, max_topics, iterations):
    perplexity = []
    coherence = []
    for num_topics in range(10,max_topics, 5):
        print("number topics",num_topics)
        x, y =evaluate_model(generate_model(common_corpus, num_topics, iterations),corpus)
        perplexity.append(x)
        coherence.append(y)
    plot_results(perplexity,coherence,range(10,max_topics, 5))    
    
def vectorized_corpus_to_matrix_similarity(vectorized_corpus, features):
    index_temp = get_tmpfile("index")
    matrix_similarity = Similarity(index_temp,corpus=vectorized_corpus, num_features=features)
    return matrix_similarity

def best_similarities(index, vectorized_corpus, matrix, number_top):
    temp = number_top + 1
    top_n = np.argpartition(matrix[vectorized_corpus[index]], -temp)[-temp:].remove(index)    
    return ind[np.argsort(a[ind])]
    

#Numera los cursos para un usuario especifico
def create_index(df, user_id):
    df_courses_index=df.loc[df['user_id']== user_id].reset_index().reset_index()
    df_courses_index["position"]=df_courses_index["level_0"]
    df_courses_index=df_courses_index.drop(columns=["level_0", "index"])
    df_courses_index["position"]=df_courses_index["position"]+1
    
    return df_courses_index
#Esta función clasifica entre train y test 
def clasificator(index , courses_viewed):
    return "test" if index>(math.floor(courses_viewed *0.7)) else "train"

def split_data_sets(df):
    frames_train=[]
    frames_test=[]

    #Recorre por cada uno de los usuarios clasificando si las filas van para train o test
    for i in df["user_id"].unique():
        data_user=create_index(df, i)
        data_user["clasification"]=data_user.apply(lambda x:clasificator(x["position"], x["courses_viewed"]), axis =1)

        frames_train.append(data_user[data_user["clasification"]=="train"])
        frames_test.append(data_user[data_user["clasification"]=="test"])

    df_train=pd.concat(frames_train)
    df_test=pd.concat(frames_test)

    return df_train, df_test

def filter_df_user(df_users, df_courses):
    df_users = df_users[df_users["course_name"].isin(df_courses["course_path"].values)]
    df_users["courses_viewed"] = df_users.groupby("user_id")["course_name"].transform('nunique')
    df_users = df_users[df_users["courses_viewed"] > 1]
    df_users = df_users[df_users["courses_viewed"] < 50]
    return df_users

def recommended_by_course(vectorized_corpus,number_topics, df_train, df_courses):
    matrix = vectorized_corpus_to_matrix_similarity(vectorized_corpus, number_topics)
    courses = df_courses["course_path"].tolist()
    recommendations = dict()
    for name, group in df_train.groupby("user_id"):
        matrix_similarity = []
        courses_index = []
        num_top_temp = len(group["course_name"]) + 5
        for course in group["course_name"]:
            index = courses.index(course)
            if len(matrix_similarity) == 0:
                matrix_similarity = matrix[vectorized_corpus[index]]
            else:
                maxtrix_similarity = matrix_similarity + matrix[vectorized_corpus[index]]
        matrix_similarity = matrix_similarity / len(group["course_name"])
        top_temp = maxtrix_similarity.argsort()[-num_top_temp:][::-1]
        top = [x for x in top_temp if x not in courses_index]
        recommendations[name] = top[:5]
    return recommendations

def binary_array_recommendations(recommendations, test_dataframe, df_courses):
    final_array = []
    len_courses = []
    courses = df_courses["course_path"].tolist()
    for name, group in test_dataframe.groupby("user_id"):
        courses_index = [courses.index(course) for course in group["course_name"].tolist()]
        temp_array = []
        for course in recommendations[name]:
            temp_array.append(int(course in courses_index))
        final_array.append(temp_array)
        if len(courses_index) >= 5:
          len_courses.append(5)
        else:
          len_courses.append(len(courses_index))
    return final_array , len_courses

def search_best_number_topics(top_topics,common_corpus, model_name, df_courses, df_train, df_test):
    metrics = []
    num_topics_by_metric = []
    for num_topics in range(5,top_topics,10):
        model = None
        if model_name == "LDA":
            model = generate_model(common_corpus, num_topics, 50)
        else:
            model = gensim.models.lsimodel.LsiModel(common_corpus,num_topics=num_topics, id2word=common_dictionary, power_iters=50)
        vectorized_corpus = model[common_corpus]
        print(type(vectorized_corpus))
        recommendations = recommended_by_course(vectorized_corpus,num_topics, df_train, df_courses)
        print("Number topics: ",num_topics)
        final_array , len_courses = binary_array_recommendations(recommendations, df_test, df_courses)
        metric = custom_mean_precision(final_array , len_courses)
        metrics.append(metric)
        num_topics_by_metric.append(num_topics)
        print("custom ",metric)
    plot_results_topics(metrics, num_topics_by_metric)
                 
def custom_mean_precision(r,k):
    precision = 0.0
    for i in range(0,len(r)):
        precision += np.sum(r[i]) / k[i]
    return precision / len(k)

# %% [markdown]
# ## Create Corpus

# %%
df = getSqlResult('SELECT course_path,id_lesson,html FROM publish')

# %%
df
# Out:
#               course_path                 id_lesson  \
# 0          work-and-money  5952555b7a44e9233cc700a8
# 1      search-better-2018  5bbf3ccd45f05d1024a3952f
# 2      search-better-2018  5b92c13aaea0dd13dce32c43
# 3      search-better-2018  5b9a852563d4780eec3a34f2
# 4            google-forms  5b9ff1f163d4780eec3a3502
# ...                   ...                       ...
# 2411   learning-wordpress  61d6f8e5c4da77185ca9f23e
# 2412   learning-wordpress  61d6fe05c4da77185ca9f240
# 2413   learning-wordpress  61d70035c4da77185ca9f242
# 2414  startup-minilessons  61a6363556eb0c1f34be92a6
# 2415  startup-minilessons  61a63f9656eb0c1f34be92a9
#
#                                                    html
# 0     What is a temp agency? If you're interested in...
# 1     Introduction to searching online The ability t...
# 2     Get more out of Google Search Search engines a...
# 3     Hidden features of Google Search Google can do...
# 4     Getting started with Google Forms Google Forms...
# ...                                                 ...
# 2411  Traffic and Social Media Visitors and Views It...
# 2412  10 Tips for Success How can you encourage your...
# 2413  Bonus Resources Here are a few websites/YouTub...
# 2414  Mini-Lesson #1: Small Business or Startup? Is ...
# 2415  Mini-Lesson #2: Startups 101 A startup is a ne...
#
# [2416 rows x 3 columns]

# %%
df["html_course"] = df.groupby("course_path")['html'].transform(lambda x: ' '.join(x))

# %%
df.drop_duplicates(subset=["course_path"], inplace=True,ignore_index=True)

# %%
df
# Out:
#               course_path                 id_lesson  \
# 0          work-and-money  5952555b7a44e9233cc700a8
# 1      search-better-2018  5bbf3ccd45f05d1024a3952f
# 2            google-forms  5b9ff1f163d4780eec3a3502
# 3        google-classroom  5bbbacb945f05d1024a3951d
# 4                snapchat  57bc92b1a17fbb1ef4203151
# ..                    ...                       ...
# 214       quiz-testing-sk  61a7c12556eb0c1f34be92bf
# 215  entrepreneurship-101  61a62c0f56eb0c1f34be92a4
# 216           zoom-basics  61b10c90a7ce105034818419
# 217    learning-wordpress  61d5e5d2c4da77185ca9f232
# 218   startup-minilessons  61a6363556eb0c1f34be92a6
#
#                                                   html  \
# 0    What is a temp agency? If you're interested in...
# 1    Introduction to searching online The ability t...
# 2    Getting started with Google Forms Google Forms...
# 3    Getting started with Google Classroom Google C...
# 4    What is Snapchat? Snapchat is a free messaging...
# ..                                                 ...
# 214                          Testing Stuff Second Test
# 215  Can I Be an Entrepreneur? What exactly is an e...
# 216  Getting Started What is Zoom? Zoom is a free s...
# 217  What is WordPress? [MOTION GRAPHICS VIDEO]: Wh...
# 218  Mini-Lesson #1: Small Business or Startup? Is ...
#
#                                            html_course
# 0    What is a temp agency? If you're interested in...
# 1    Introduction to searching online The ability t...
# 2    Getting started with Google Forms Google Forms...
# 3    Getting started with Google Classroom Google C...
# 4    What is Snapchat? Snapchat is a free messaging...
# ..                                                 ...
# 214                          Testing Stuff Second Test
# 215  Can I Be an Entrepreneur? What exactly is an e...
# 216  Getting Started What is Zoom? Zoom is a free s...
# 217  What is WordPress? [MOTION GRAPHICS VIDEO]: Wh...
# 218  Mini-Lesson #1: Small Business or Startup? Is ...
#
# [219 rows x 4 columns]

# %%
df["tokens"] = preprocess_text(df["html_course"])
common_dictionary = Dictionary(df["tokens"])

# %%
len(common_dictionary)
# Out:
# 8581

# %%
common_dictionary.filter_extremes(no_above=0.95)

# %%
len(common_dictionary)
# Out:
# 2711

# %%
common_corpus = [common_dictionary.doc2bow(text) for text in df["tokens"]]

# %%
common_dictionary.token2id
# Out:
# {'abl': 0,
#  'agenc': 1,
#  'allow': 2,
#  'appli': 3,
#  'applic': 4,
#  'ask': 5,
#  'assess': 6,
#  'assign': 7,
#  'awai': 8,
#  'base': 9,
#  'best': 10,
#  'better': 11,
#  'bit': 12,
#  'board': 13,
#  'call': 14,
#  'career': 15,
#  'case': 16,
#  'certain': 17,
#  'check': 18,
#  'choos': 19,
#  'come': 20,
#  'compani': 21,
#  'complet': 22,
#  'consid': 23,
#  'contact': 24,
#  'current': 25,
#  'decid': 26,
#  'decis': 27,
#  'depend': 28,
#  'describ': 29,
#  'descript': 30,
#  'determin': 31,
#  'differ': 32,
#  'directli': 33,
#  'duti': 34,
#  'employ': 35,
#  'employe': 36,
#  'estim': 37,
#  'everyth': 38,
#  'experi': 39,
#  'factor': 40,
#  'fee': 41,
#  'feel': 42,
#  'field': 43,
#  'fit': 44,
#  'flag': 45,
#  'flow': 46,
#  'forward': 47,
#  'gener': 48,
#  'get': 49,
#  'given': 50,
#  'go': 51,
#  'good': 52,
#  'grasp': 53,
#  'heart': 54,
#  'hire': 55,
#  'hope': 56,
#  'idea': 57,
#  'import': 58,
#  'includ': 59,
#  'inform': 60,
#  'instead': 61,
#  'interest': 62,
#  'interview': 63,
#  'job': 64,
#  'know': 65,
#  'knowledg': 66,
#  'learn': 67,
#  'like': 68,
#  'locat': 69,
#  'long': 70,
#  'look': 71,
#  'make': 72,
#  'match': 73,
#  'mean': 74,
#  'media': 75,
#  'need': 76,
#  'new': 77,
#  'note': 78,
#  'on': 79,
#  'option': 80,
#  'organ': 81,
#  'pai': 82,
#  'paid': 83,
#  'particular': 84,
#  'paycheck': 85,
#  'perman': 86,
#  'place': 87,
#  'posit': 88,
#  'potenti': 89,
#  'process': 90,
#  'profession': 91,
#  'program': 92,
#  'question': 93,
#  'rate': 94,
#  'recruit': 95,
#  'red': 96,
#  'relat': 97,
#  'reliabl': 98,
#  'reput': 99,
#  'requir': 100,
#  'research': 101,
#  'resourc': 102,
#  'review': 103,
#  'right': 104,
#  'role': 105,
#  'scam': 106,
#  'schedul': 107,
#  'send': 108,
#  'servic': 109,
#  'set': 110,
#  'shop': 111,
#  'similar': 112,
#  'site': 113,
#  'skill': 114,
#  'social': 115,
#  'special': 116,
#  'specif': 117,
#  'standard': 118,
#  'start': 119,
#  'subject': 120,
#  'sure': 121,
#  'technic': 122,
#  'temporari': 123,
#  'test': 124,
#  'thing': 125,
#  'touch': 126,
#  'tradit': 127,
#  'try': 128,
#  'tutori': 129,
#  'typic': 130,
#  'unlik': 131,
#  'us': 132,
#  'usual': 133,
#  'vari': 134,
#  'video': 135,
#  'want': 136,
#  'watch': 137,
#  'work': 138,
#  'worker': 139,
#  'abbrevi': 140,
#  'abil': 141,
#  'access': 142,
#  'account': 143,
#  'accur': 144,
#  'action': 145,
#  'ad': 146,
#  'add': 147,
#  'addit': 148,
#  'address': 149,
#  'adopt': 150,
#  'advanc': 151,
#  'afraid': 152,
#  'anim': 153,
#  'annoi': 154,
#  'answer': 155,
#  'appear': 156,
#  'arrow': 157,
#  'articl': 158,
#  'artist': 159,
#  'aspect': 160,
#  'autocomplet': 161,
#  'automat': 162,
#  'bar': 163,
#  'basic': 164,
#  'bing': 165,
#  'blog': 166,
#  'book': 167,
#  'box': 168,
#  'brand': 169,
#  'brief': 170,
#  'bring': 171,
#  'brows': 172,
#  'browser': 173,
#  'builtin': 174,
#  'busi': 175,
#  'button': 176,
#  'calcul': 177,
#  'came': 178,
#  'capit': 179,
#  'carrier': 180,
#  'chang': 181,
#  'chrome': 182,
#  'citi': 183,
#  'click': 184,
#  'close': 185,
#  'code': 186,
#  'coffe': 187,
#  'color': 188,
#  'common': 189,
#  'complic': 190,
#  'conduct': 191,
#  'confus': 192,
#  'contain': 193,
#  'content': 194,
#  'continu': 195,
#  'convers': 196,
#  'convert': 197,
#  'cool': 198,
#  'corner': 199,
#  'correct': 200,
#  'creat': 201,
#  'creativ': 202,
#  'critic': 203,
#  'custom': 204,
#  'dai': 205,
#  'date': 206,
#  'default': 207,
#  'defin': 208,
#  'definit': 209,
#  'deliv': 210,
#  'desir': 211,
#  'detail': 212,
#  'dictionari': 213,
#  'difficult': 214,
#  'digit': 215,
#  'direct': 216,
#  'distanc': 217,
#  'distract': 218,
#  'divid': 219,
#  'dog': 220,
#  'drive': 221,
#  'earth': 222,
#  'easi': 223,
#  'easytous': 224,
#  'edit': 225,
#  'effect': 226,
#  'engin': 227,
#  'english': 228,
#  'ensur': 229,
#  'enter': 230,
#  'evalu': 231,
#  'everydai': 232,
#  'exact': 233,
#  'exampl': 234,
#  'exist': 235,
#  'expand': 236,
#  'explor': 237,
#  'f': 238,
#  'fact': 239,
#  'fail': 240,
#  'fast': 241,
#  'featur': 242,
#  'file': 243,
#  'filter': 244,
#  'final': 245,
#  'find': 246,
#  'fine': 247,
#  'focu': 248,
#  'focus': 249,
#  'follow': 250,
#  'food': 251,
#  'forecast': 252,
#  'format': 253,
#  'free': 254,
#  'fullsiz': 255,
#  'function': 256,
#  'ga': 257,
#  'game': 258,
#  'give': 259,
#  'glass': 260,
#  'gmail': 261,
#  'googl': 262,
#  'googlecom': 263,
#  'grammar': 264,
#  'great': 265,
#  'green': 266,
#  'handl': 267,
#  'have': 268,
#  'heard': 269,
#  'help': 270,
#  'hesit': 271,
#  'hidden': 272,
#  'home': 273,
#  'homepag': 274,
#  'hotspot': 275,
#  'icon': 276,
#  'ignor': 277,
#  'imag': 278,
#  'immedi': 279,
#  'incorrect': 280,
#  'incred': 281,
#  'indepth': 282,
#  'instant': 283,
#  'instruct': 284,
#  'interact': 285,
#  'interfac': 286,
#  'internet': 287,
#  'introduct': 288,
#  'investig': 289,
#  'involv': 290,
#  'irrelev': 291,
#  'judgment': 292,
#  'kei': 293,
#  'keyword': 294,
#  'languag': 295,
#  'larg': 296,
#  'lesson': 297,
#  'let': 298,
#  'level': 299,
#  'life': 300,
#  'link': 301,
#  'list': 302,
#  'literaci': 303,
#  'littl': 304,
#  'live': 305,
#  'local': 306,
#  'lot': 307,
#  'magnifi': 308,
#  'mainli': 309,
#  'map': 310,
#  'math': 311,
#  'matter': 312,
#  'mayb': 313,
#  'meant': 314,
#  'measur': 315,
#  'method': 316,
#  'mile': 317,
#  'mind': 318,
#  'minimum': 319,
#  'mislead': 320,
#  'misspel': 321,
#  'mistak': 322,
#  'mous': 323,
#  'narrow': 324,
#  'natur': 325,
#  'near': 326,
#  'nearbi': 327,
#  'necessari': 328,
#  'normal': 329,
#  'number': 330,
#  'numer': 331,
#  'occas': 332,
#  'offer': 333,
#  'old': 334,
#  'onlin': 335,
#  'open': 336,
#  'overal': 337,
#  'page': 338,
#  'part': 339,
#  'perfect': 340,
#  'perform': 341,
#  'person': 342,
#  'pet': 343,
#  'phrase': 344,
#  'pick': 345,
#  'pictur': 346,
#  'piec': 347,
#  'plenti': 348,
#  'plu': 349,
#  'popular': 350,
#  'portion': 351,
#  'possess': 352,
#  'post': 353,
#  'power': 354,
#  'present': 355,
#  'press': 356,
#  'pretti': 357,
#  'preview': 358,
#  'price': 359,
#  'probabl': 360,
#  'problem': 361,
#  'product': 362,
#  'provid': 363,
#  'public': 364,
#  'punctuat': 365,
#  'queri': 366,
#  'quickli': 367,
#  'raleigh': 368,
#  'rare': 369,
#  'read': 370,
#  'recogn': 371,
#  'rectangl': 372,
#  'refin': 373,
#  'relev': 374,
#  'rememb': 375,
#  'result': 376,
#  'rout': 377,
#  'sai': 378,
#  'score': 379,
#  'search': 380,
#  'second': 381,
#  'select': 382,
#  'sentenc': 383,
#  'shape': 384,
#  'sift': 385,
#  'sign': 386,
#  'simpl': 387,
#  'simpli': 388,
#  'simplifi': 389,
#  'singl': 390,
#  'size': 391,
#  'solv': 392,
#  'song': 393,
#  'sort': 394,
#  'sourc': 395,
#  'spanish': 396,
#  'spell': 397,
#  'sport': 398,
#  'squar': 399,
#  'state': 400,
#  'step': 401,
#  'stock': 402,
#  'strategi': 403,
#  'success': 404,
#  'suggest': 405,
#  'summari': 406,
#  'tab': 407,
#  'take': 408,
#  'techniqu': 409,
#  'temperatur': 410,
#  'term': 411,
#  'text': 412,
#  'think': 413,
#  'time': 414,
#  'tip': 415,
#  'titl': 416,
#  'tool': 417,
#  'topic': 418,
#  'track': 419,
#  'translat': 420,
#  'triangl': 421,
#  'trick': 422,
#  'troubl': 423,
#  'type': 424,
#  'understand': 425,
#  'uniqu': 426,
#  'updat': 427,
#  'userfriendli': 428,
#  'util': 429,
#  'version': 430,
#  'view': 431,
#  'visit': 432,
#  'vocabulari': 433,
#  'wai': 434,
#  'weather': 435,
#  'webpag': 436,
#  'websit': 437,
#  'weight': 438,
#  'wellknown': 439,
#  'wikipedia': 440,
#  'word': 441,
#  'worri': 442,
#  'yahoo': 443,
#  'youtub': 444,
#  'zip': 445,
#  'accept': 446,
#  'accord': 447,
#  'adjust': 448,
#  'analysi': 449,
#  'analyz': 450,
#  'app': 451,
#  'arrai': 452,
#  'asterisk': 453,
#  'attach': 454,
#  'audienc': 455,
#  'avail': 456,
#  'averag': 457,
#  'birthdai': 458,
#  'blank': 459,
#  'broken': 460,
#  'categori': 461,
#  'chart': 462,
#  'checkbox': 463,
#  'choic': 464,
#  'chose': 465,
#  'chosen': 466,
#  'class': 467,
#  'classroom': 468,
#  'closer': 469,
#  'collect': 470,
#  'column': 471,
#  'complex': 472,
#  'confer': 473,
#  'copi': 474,
#  'count': 475,
#  'cours': 476,
#  'cover': 477,
#  'd': 478,
#  'data': 479,
#  'delet': 480,
#  'destin': 481,
#  'displai': 482,
#  'distribut': 483,
#  'document': 484,
#  'drag': 485,
#  'drop': 486,
#  'dropdown': 487,
#  'duplic': 488,
#  'earn': 489,
#  'easier': 490,
#  'easiest': 491,
#  'easili': 492,
#  'editor': 493,
#  'educ': 494,
#  'email': 495,
#  'emb': 496,
#  'embed': 497,
#  'end': 498,
#  'entir': 499,
#  'event': 500,
#  'expect': 501,
#  'facebook': 502,
#  'fairli': 503,
#  'familiar': 504,
#  'far': 505,
#  'feedback': 506,
#  'felt': 507,
#  'fill': 508,
#  'finish': 509,
#  'form': 510,
#  'formula': 511,
#  'friend': 512,
#  'futur': 513,
#  'galleri': 514,
#  'gather': 515,
#  'grade': 516,
#  'greater': 517,
#  'handi': 518,
#  'happi': 519,
#  'hear': 520,
#  'held': 521,
#  'host': 522,
#  'html': 523,
#  'incorpor': 524,
#  'individu': 525,
#  'insert': 526,
#  'insid': 527,
#  'intern': 528,
#  'invit': 529,
#  'kind': 530,
#  'later': 531,
#  'leav': 532,
#  'left': 533,
#  'limit': 534,
#  'log': 535,
#  'longer': 536,
#  'lowerleft': 537,
#  'luckili': 538,
#  'manag': 539,
#  'manipul': 540,
#  'manual': 541,
#  'mark': 542,
#  'meet': 543,
#  'mention': 544,
#  'menu': 545,
#  'messag': 546,
#  'miss': 547,
#  'multipl': 548,
#  'navig': 549,
#  'notic': 550,
#  'notif': 551,
#  'order': 552,
#  'overview': 553,
#  'overwhelm': 554,
#  'pane': 555,
#  'paragraph': 556,
#  'parent': 557,
#  'parti': 558,
#  'past': 559,
#  'peopl': 560,
#  'pivot': 561,
#  'plan': 562,
#  'point': 563,
#  'possibl': 564,
#  'prefer': 565,
#  'progress': 566,
#  'quiz': 567,
#  'quizz': 568,
#  'readi': 569,
#  'realworld': 570,
#  'receipt': 571,
#  'receiv': 572,
#  'recent': 573,
#  'recipi': 574,
#  'releas': 575,
#  'remind': 576,
#  'repeat': 577,
#  'respond': 578,
#  'respons': 579,
#  'row': 580,
#  'satisfi': 581,
#  'save': 582,
#  'scale': 583,
#  'scratch': 584,
#  'screen': 585,
#  'section': 586,
#  'seen': 587,
#  'sensit': 588,
#  'sent': 589,
#  'separ': 590,
#  'share': 591,
#  'sheet': 592,
#  'short': 593,
#  'show': 594,
#  'shown': 595,
#  'sidebar': 596,
#  'signup': 597,
#  'smaller': 598,
#  'spreadsheet': 599,
#  'store': 600,
#  'student': 601,
#  'submit': 602,
#  'subtract': 603,
#  'summar': 604,
#  'survei': 605,
#  'switch': 606,
#  'tabl': 607,
#  'taken': 608,
#  'talk': 609,
#  'teacher': 610,
#  'templat': 611,
#  'toggl': 612,
#  'toolbar': 613,
#  'topright': 614,
#  'total': 615,
#  'turn': 616,
#  'twitter': 617,
#  'uncheck': 618,
#  'untitl': 619,
#  'upload': 620,
#  'upperright': 621,
#  'valu': 622,
#  'varieti': 623,
#  'wait': 624,
#  'wider': 625,
#  'wordpress': 626,
#  'worksheet': 627,
#  'worth': 628,
#  'write': 629,
#  'written': 630,
#  'activ': 631,
#  'actual': 632,
#  'administr': 633,
#  'affect': 634,
#  'android': 635,
#  'announc': 636,
#  'area': 637,
#  'calendar': 638,
#  'cloudbas': 639,
#  'collabor': 640,
#  'comment': 641,
#  'commun': 642,
#  'confirm': 643,
#  'consider': 644,
#  'control': 645,
#  'correspond': 646,
#  'coupl': 647,
#  'daili': 648,
#  'devic': 649,
#  'dialog': 650,
#  'doc': 651,
#  'download': 652,
#  'essai': 653,
#  'export': 654,
#  'flexibl': 655,
#  'g': 656,
#  'gear': 657,
#  'grant': 658,
#  'group': 659,
#  'guid': 660,
#  'heavili': 661,
#  'inbox': 662,
#  'iphon': 663,
#  'join': 664,
#  'lengthi': 665,
#  'main': 666,
#  'materi': 667,
#  'mobil': 668,
#  'name': 669,
#  'notifi': 670,
#  'panel': 671,
#  'pose': 672,
#  'print': 673,
#  'privaci': 674,
#  'privat': 675,
#  'pull': 676,
#  'regardless': 677,
#  'reli': 678,
#  'reset': 679,
#  'return': 680,
#  'room': 681,
#  'school': 682,
#  'secur': 683,
#  'serv': 684,
#  'soon': 685,
#  'split': 686,
#  'stream': 687,
#  'studi': 688,
#  'suit': 689,
#  'task': 690,
#  'teach': 691,
#  'thirdparti': 692,
#  'timelin': 693,
#  'todo': 694,
#  'trip': 695,
#  'unit': 696,
#  'upcom': 697,
#  'url': 698,
#  'visual': 699,
#  'weekli': 700,
#  'year': 701,
#  'big': 702,
#  'camera': 703,
#  'connect': 704,
#  'disappear': 705,
#  'draw': 706,
#  'embarrass': 707,
#  'famili': 708,
#  'favorit': 709,
#  'flash': 710,
#  'goofi': 711,
#  'illustr': 712,
#  'instal': 713,
#  'io': 714,
#  'memori': 715,
#  'moment': 716,
#  'network': 717,
#  'obviou': 718,
#  'ok': 719,
#  'photo': 720,
#  'profil': 721,
#  'repli': 722,
#  'silli': 723,
#  'small': 724,
#  'smartphon': 725,
#  'snap': 726,
#  'sound': 727,
#  'stori': 728,
#  'swipe': 729,
#  'tap': 730,
#  'todai': 731,
#  'user': 732,
#  'aid': 733,
#  'altern': 734,
#  'approach': 735,
#  'background': 736,
#  'bottomright': 737,
#  'build': 738,
#  'compat': 739,
#  'concept': 740,
#  'consum': 741,
#  'cost': 742,
#  'dashboard': 743,
#  'dynam': 744,
#  'element': 745,
#  'engag': 746,
#  'escap': 747,
#  'eyecatch': 748,
#  'fewer': 749,
#  'forth': 750,
#  'frame': 751,
#  'fullscreen': 752,
#  'gone': 753,
#  'hover': 754,
#  'issu': 755,
#  'keyboard': 756,
#  'microsoft': 757,
#  'mode': 758,
#  'move': 759,
#  'movement': 760,
#  'object': 761,
#  'path': 762,
#  'powerpoint': 763,
#  'practic': 764,
#  'predesign': 765,
#  'pro': 766,
#  'projector': 767,
#  'reason': 768,
#  'redo': 769,
#  'rel': 770,
#  'remot': 771,
#  'reorder': 772,
#  'run': 773,
#  'sampl': 774,
#  'scheme': 775,
#  'sens': 776,
#  'shortcut': 777,
#  'slide': 778,
#  'softwar': 779,
#  'space': 780,
#  'stuck': 781,
#  'style': 782,
#  'transit': 783,
#  'travel': 784,
#  'undo': 785,
#  'unlock': 786,
#  'upgrad': 787,
#  'viewer': 788,
#  'web': 789,
#  'webbas': 790,
#  'wonder': 791,
#  'zoom': 792,
#  'attend': 793,
#  'belong': 794,
#  'dedic': 795,
#  'enjoi': 796,
#  'gain': 797,
#  'greet': 798,
#  'guest': 799,
#  'hand': 800,
#  'hobbi': 801,
#  'initi': 802,
#  'inperson': 803,
#  'member': 804,
#  'monei': 805,
#  'month': 806,
#  'monthli': 807,
#  'occasion': 808,
#  'occur': 809,
#  'offlin': 810,
#  'origin': 811,
#  'park': 812,
#  'particip': 813,
#  'passion': 814,
#  'period': 815,
#  'polici': 816,
#  'polit': 817,
#  'popup': 818,
#  'prompt': 819,
#  'reach': 820,
#  'registr': 821,
#  'remov': 822,
#  'successfulli': 823,
#  'tend': 824,
#  'verifi': 825,
#  'ye': 826,
#  'alert': 827,
#  'audio': 828,
#  'bottomleft': 829,
#  'caller': 830,
#  'canada': 831,
#  'chat': 832,
#  'coordin': 833,
#  'declin': 834,
#  'desktop': 835,
#  'discontinu': 836,
#  'extens': 837,
#  'hangout': 838,
#  'ident': 839,
#  'incom': 840,
#  'microphon': 841,
#  'middl': 842,
#  'minim': 843,
#  'music': 844,
#  'outsid': 845,
#  'phone': 846,
#  'platform': 847,
#  'plugin': 848,
#  'previous': 849,
#  'regular': 850,
#  'reopen': 851,
#  'ring': 852,
#  'screenshot': 853,
#  'speaker': 854,
#  'stepbystep': 855,
#  'support': 856,
#  'upperleft': 857,
#  'voic': 858,
#  'window': 859,
#  'agre': 860,
#  'asid': 861,
#  'begin': 862,
#  'benefit': 863,
#  'cell': 864,
#  'cellular': 865,
#  'charg': 866,
#  'comput': 867,
#  'countri': 868,
#  'detect': 869,
#  'disabl': 870,
#  'encrypt': 871,
#  'expens': 872,
#  'hold': 873,
#  'librari': 874,
#  'listen': 875,
#  'minut': 876,
#  'mute': 877,
#  'pdf': 878,
#  'procedur': 879,
#  'protect': 880,
#  'record': 881,
#  'setup': 882,
#  'slideshow': 883,
#  'welcom': 884,
#  'wifi': 885,
#  'clipboard': 886,
#  'cloud': 887,
#  'dropbox': 888,
#  'especi': 889,
#  'excel': 890,
#  'folder': 891,
#  'gb': 892,
#  'gigabyt': 893,
#  'happen': 894,
#  'hide': 895,
#  'highlight': 896,
#  'larger': 897,
#  'offic': 898,
#  'onscreen': 899,
#  'oper': 900,
#  'permiss': 901,
#  'previou': 902,
#  'proce': 903,
#  'project': 904,
#  'redirect': 905,
#  'respect': 906,
#  's': 907,
#  'scan': 908,
#  'slightli': 909,
#  'storag': 910,
#  'sync': 911,
#  'textbas': 912,
#  'x': 913,
#  'alongsid': 914,
#  'appropri': 915,
#  'caption': 916,
#  'doubleclick': 917,
#  'explain': 918,
#  'fulli': 919,
#  'gcflearnfreeorg': 920,
#  'major': 921,
#  'mp': 922,
#  'plai': 923,
#  'player': 924,
#  'rightclick': 925,
#  'simpler': 926,
#  'uptod': 927,
#  'vast': 928,
#  'wish': 929,
#  'absolut': 930,
#  'adob': 931,
#  'amazon': 932,
#  'appl': 933,
#  'boot': 934,
#  'budget': 935,
#  'bui': 936,
#  'carefulli': 937,
#  'center': 938,
#  'central': 939,
#  'cheapest': 940,
#  'clear': 941,
#  'compar': 942,
#  'compon': 943,
#  'con': 944,
#  'condit': 945,
#  'consist': 946,
#  'deal': 947,
#  'ebai': 948,
#  'fan': 949,
#  'faster': 950,
#  'fix': 951,
#  'forev': 952,
#  'forum': 953,
#  'guarante': 954,
#  'habit': 955,
#  'hard': 956,
#  'higher': 957,
#  'howto': 958,
#  'hunt': 959,
#  'impact': 960,
#  'ipad': 961,
#  'laptop': 962,
#  'light': 963,
#  'loud': 964,
#  'low': 965,
#  'lowcost': 966,
#  'machin': 967,
#  'manner': 968,
#  'manufactur': 969,
#  'market': 970,
#  'migrat': 971,
#  'minor': 972,
#  'model': 973,
#  'newer': 974,
#  'nois': 975,
#  'offici': 976,
#  'older': 977,
#  'os': 978,
#  'outdat': 979,
#  'patch': 980,
#  'pc': 981,
#  'photoshop': 982,
#  'pixlr': 983,
#  'prevent': 984,
#  'processor': 985,
#  'purchas': 986,
#  'rang': 987,
#  'real': 988,
#  'recommend': 989,
#  'replac': 990,
#  'report': 991,
#  'restor': 992,
#  'retail': 993,
#  'samsung': 994,
#  'seek': 995,
#  'sell': 996,
#  'seller': 997,
#  'slow': 998,
#  'solut': 999,
#  ...}

# %%
#dictionary.save_as_text('c:\\research\\gensimDictionary.txt')

# %% [markdown]
# ## Find best number topics

# %%
#find_best_topic(common_corpus, 200, 50)

# %% [markdown]
# ## Testing recommendations

# %%
df_users = pd.read_csv("final_data_set.csv", sep=",",low_memory=False,index_col="Unnamed: 0")
df_users = df_users.drop_duplicates(subset=["user_id", "course_name"])
df_users.shape
# Out:
# (32578, 14)

# %%
df_users = filter_df_user(df_users ,df)
# Out:
# /tmp/ipykernel_2447220/1605553220.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_users["courses_viewed"] = df_users.groupby("user_id")["course_name"].transform('nunique')

# %%
df_users.shape
# Out:
# (32309, 14)

# %%
df_train, df_test = split_data_sets(df_users)

# %%
search_best_number_topics(360,common_corpus, "LDA", df, df_train, df_test)
# Out:
# Number topics:  5
# custom  0.08039048431428296
# Number topics:  15
# custom  0.14187754715192913
# Number topics:  25
# custom  0.13421002748554664
# Number topics:  35
# custom  0.1357525353047107
# Number topics:  45
# custom  0.14210738318642813
# Number topics:  55
# custom  0.14321628281679488
# Number topics:  65
# custom  0.1427684579660699
# Number topics:  75
# custom  0.14421618803904876
# Number topics:  85
# custom  0.1562505923609139
# Number topics:  95
# custom  0.1423230025589994
# Number topics:  105
# custom  0.15074874419486342
# Number topics:  115
# custom  0.13081461472846195
# Number topics:  125
# custom  0.13345417495971967
# Number topics:  135
# custom  0.147012131551512
# Number topics:  145
# custom  0.14648374561652955
# Number topics:  155
# custom  0.14411193251824503
# Number topics:  165
# custom  0.15407307364230907
# Number topics:  175
# custom  0.15067055255426065
# Number topics:  185
# custom  0.1348829494834615
# Number topics:  195
# custom  0.13998436167187975
# Number topics:  205
# custom  0.14759975357786015
# Number topics:  215
# custom  0.14425646858117747
# Number topics:  225
# custom  0.16198701544877286
# Number topics:  235
# custom  0.14615202350488138
# Number topics:  245
# custom  0.14091081414084003
# Number topics:  255
# custom  0.13354421381859563
# Number topics:  265
# custom  0.13632357122547648
# Number topics:  275
# custom  0.13821912614918044
# Number topics:  285
# custom  0.1420126054402429
# Number topics:  295
# custom  0.14705478153729531
# Number topics:  305
# custom  0.14468533788266552
# Number topics:  315
# custom  0.14856411714529466
# Number topics:  325
# custom  0.13901525921713606
# Number topics:  335
# custom  0.1532295517012608
# Number topics:  345
# custom  0.146692256658137
# Number topics:  355
# custom  0.15905364420434104

# %%
search_best_number_topics(360,common_corpus, "LSI", df, df_train, df_test)
# Out:
# Number topics:  5
# custom  0.09259548857928164
# Number topics:  15
# custom  0.13334518055160674
# Number topics:  25
# custom  0.1419178276940577
# Number topics:  35
# custom  0.1418917638138568
# Number topics:  45
# custom  0.1455880959150795
# Number topics:  55
# custom  0.1411382807316845
# Number topics:  65
# custom  0.14391763813856537
# Number topics:  75
# custom  0.14827267557577511
# Number topics:  85
# custom  0.1522272770353524
# Number topics:  95
# custom  0.1545445929295805
# Number topics:  105
# custom  0.1577978390673873
# Number topics:  115
# custom  0.16257700691877566
# Number topics:  125
# custom  0.16170031276656266
# Number topics:  135
# custom  0.16474504786276203
# Number topics:  145
# custom  0.16592266135911313
# Number topics:  155
# custom  0.16706947208795397
# Number topics:  165
# custom  0.1655411809307177
# Number topics:  175
# custom  0.16604350298549925
# Number topics:  185
# custom  0.166659558335703
# Number topics:  195
# custom  0.16681357217325393
# Number topics:  205
# custom  0.167216377594541
# Number topics:  215
# custom  0.16702208321486137
# Number topics:  225
# custom  0.16711686096104658
# Number topics:  235
# custom  0.16711686096104658
# Number topics:  245
# custom  0.16711686096104658
# Number topics:  255
# custom  0.16711686096104658
# Number topics:  265
# custom  0.16711686096104658
# Number topics:  275
# custom  0.16711686096104658
# Number topics:  285
# custom  0.16711686096104658
# Number topics:  295
# custom  0.16711686096104658
# Number topics:  305
# custom  0.16711686096104658
# Number topics:  315
# custom  0.16711686096104658
# Number topics:  325
# custom  0.16711686096104658
# Number topics:  335
# custom  0.16711686096104658
# Number topics:  345
# custom  0.16711686096104658
# Number topics:  355
# custom  0.16711686096104658

# %%
generate_sr_model_transformer(df["html_course"],"all-roberta-large-v1", df_test, df_train, df)
# Out:
# custom  0.15306369064543673

# %%
generate_sr_model_transformer(df["html_course"],"all-mpnet-base-v2", df_test, df_train, df)
# Out:
# custom  0.18722632925789034

# %%
generate_sr_model_transformer(df["html_course"],"paraphrase-multilingual-mpnet-base-v2", df_test, df_train, df)
# Out:
# Downloading:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.77k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/723 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/402 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# custom  0.15076296085679106

# %%
generate_sr_model_transformer(df["html_course"],"all-MiniLM-L12-v2", df_test, df_train, df)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/573 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/134M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/352 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# custom  0.1493863140934512

# %%
generate_sr_model_transformer(df["html_course"],"paraphrase-multilingual-MiniLM-L12-v2", df_test, df_train, df)
# Out:
# Downloading:   0%|          | 0.00/968 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.79k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/645 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/14.8M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# custom  0.1398374561652927

# %% [markdown]
# # Prueba estadistica

# %%
def evaluate_model_matrix(common_corpus,model_name, d_train, df_test, df_courses):
    vectorized_corpus = None
    if model_name == "LDA":
        model = gensim.models.LdaModel.load("./models/LDA_model", mmap='r')
        vectorized_corpus = model[common_corpus]
    elif model_name == "LSI":
        model = gensim.models.lsimodel.LsiModel.load("./models/LSI_model")
        vectorized_corpus = model[common_corpus]
    else:
        model = SentenceTransformer(model_name)
        embeddings = model.encode(df_courses["html_course"])
        vectorized_corpus = [list(zip(range(0,len(embeddings[0])),vector)) for vector in embeddings]
        
    recommendations = recommended_by_course(vectorized_corpus,len(vectorized_corpus[0]), df_train, df_courses)
    final_array , len_courses = binary_array_recommendations(recommendations, df_test, df_courses)
    return final_array , len_courses

    
def temp_function_2():
    model = gensim.models.lsimodel.LsiModel(common_corpus,num_topics=165, id2word=common_dictionary, power_iters=50)
    model.save("./models/LSI_model")
    
    model = generate_model(common_corpus, 225, 50)
    model.save("./models/LDA_model")
    
def random_split(dataframe, field_name, size):
    return dataframe.loc[dataframe[field_name].isin(np.random.choice(dataframe[field_name].unique(), size=size, replace=False))]

# %%
temp_function_2()
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
def evaluate_models_by_folders(train_df,test_df,df_course,number_folders,size, file_name, common_corpus):
    with open(file_name, mode='w', newline="") as data_user_file:
        doc_writer = csv.writer(data_user_file, delimiter=',', quotechar='"')   
        doc_writer.writerow(["Folder","Model","Custom_metric"])
        for i in tqdm(range(0,number_folders)):
            df = random_split(train_df, "user_id", size=size)
            models = ["all-roberta-large-v1","all-mpnet-base-v2","paraphrase-multilingual-mpnet-base-v2","all-MiniLM-L12-v2","paraphrase-multilingual-MiniLM-L12-v2","LDA","LSI"]
            for model_name in tqdm(models, leave=False):
                final_array , len_courses = evaluate_model_matrix(common_corpus,model_name, train_df, test_df, df_course)
                ct_metric = custom_mean_precision(final_array , len_courses)
                doc_writer.writerow([i,model_name,ct_metric])

# %%
df_train["user_id"].nunique()
# Out:
# 7034

# %%
evaluate_models_by_folders(df_train,df_test,df,100,3000, "results_CB_models", common_corpus)
# Out:
#   0%|                                                   | 0/100 [00:00<?, ?it/s]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  14%|██████▎                                     | 1/7 [03:30<21:04, 210.71s/it]
#  29%|████████████▌                               | 2/7 [05:39<13:32, 162.47s/it]
#  43%|██████████████████▊                         | 3/7 [07:24<09:04, 136.18s/it]
#  57%|█████████████████████████▏                  | 4/7 [08:20<05:13, 104.50s/it]
#  71%|████████████████████████████████▏            | 5/7 [09:16<02:54, 87.05s/it]
#  86%|██████████████████████████████████████▌      | 6/7 [10:48<01:28, 88.81s/it]
# 100%|█████████████████████████████████████████████| 7/7 [11:04<00:00, 65.01s/it]
#   1%|▍                                      | 1/100 [11:04<18:16:34, 664.59s/it]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  14%|██████▎                                     | 1/7 [03:30<21:01, 210.29s/it]
#  29%|████████████▌                               | 2/7 [05:39<13:31, 162.35s/it]
#  43%|██████████████████▊                         | 3/7 [07:23<09:04, 136.01s/it]
#  57%|█████████████████████████▏                  | 4/7 [08:19<05:12, 104.24s/it]
#  71%|████████████████████████████████▏            | 5/7 [09:15<02:53, 86.94s/it]
#  86%|██████████████████████████████████████▌      | 6/7 [10:48<01:28, 88.92s/it]
# 100%|█████████████████████████████████████████████| 7/7 [11:04<00:00, 65.18s/it]
#   2%|▊                                      | 2/100 [22:09<18:05:32, 664.62s/it]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  14%|██████▎                                     | 1/7 [03:29<20:59, 209.93s/it]
#  29%|████████████▌                               | 2/7 [05:38<13:31, 162.31s/it]
#  43%|██████████████████▊                         | 3/7 [07:23<09:04, 136.18s/it]
#  57%|█████████████████████████▏                  | 4/7 [08:19<05:12, 104.27s/it]
#  71%|████████████████████████████████▏            | 5/7 [09:16<02:54, 87.19s/it]
#  86%|██████████████████████████████████████▌      | 6/7 [10:48<01:28, 88.85s/it]
# 100%|█████████████████████████████████████████████| 7/7 [11:04<00:00, 65.17s/it]
#   3%|█▏                                     | 3/100 [33:13<17:54:34, 664.68s/it]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  14%|██████▎                                     | 1/7 [03:29<20:56, 209.50s/it]
#  29%|████████████▌                               | 2/7 [05:38<13:30, 162.04s/it]
#  43%|██████████████████▊                         | 3/7 [07:23<09:04, 136.02s/it]
#  57%|█████████████████████████▏                  | 4/7 [08:18<05:12, 104.24s/it]
#  71%|████████████████████████████████▏            | 5/7 [09:16<02:54, 87.42s/it]
#  86%|██████████████████████████████████████▌      | 6/7 [10:46<01:28, 88.42s/it]
# 100%|█████████████████████████████████████████████| 7/7 [11:03<00:00, 64.90s/it]
#   4%|█▌                                     | 4/100 [44:17<17:42:37, 664.14s/it]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  14%|██████▎                                     | 1/7 [03:29<20:54, 209.09s/it]
#  29%|████████████▌                               | 2/7 [05:43<13:44, 164.97s/it]
#  43%|██████████████████▊                         | 3/7 [07:37<09:26, 141.71s/it]
#  57%|█████████████████████████▏                  | 4/7 [08:32<05:23, 107.67s/it]
#  71%|████████████████████████████████▏            | 5/7 [09:29<02:58, 89.38s/it]
#  86%|██████████████████████████████████████▌      | 6/7 [11:02<01:30, 90.53s/it]
# 100%|█████████████████████████████████████████████| 7/7 [11:18<00:00, 66.24s/it]
#   5%|█▉                                     | 5/100 [55:35<17:39:49, 669.37s/it]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  14%|██████▎                                     | 1/7 [03:29<20:58, 209.77s/it]
#  29%|████████████▌                               | 2/7 [05:37<13:26, 161.35s/it]
#  43%|██████████████████▊                         | 3/7 [07:22<09:02, 135.55s/it]
#  57%|█████████████████████████▏                  | 4/7 [08:17<05:11, 103.96s/it]
#  71%|████████████████████████████████▏            | 5/7 [09:14<02:54, 87.07s/it]
#  86%|██████████████████████████████████████▌      | 6/7 [10:48<01:29, 89.19s/it]
# 100%|█████████████████████████████████████████████| 7/7 [11:04<00:00, 65.36s/it]
#   6%|██▏                                  | 6/100 [1:06:40<17:26:00, 667.66s/it]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  14%|██████▎                                     | 1/7 [03:29<20:58, 209.77s/it]
#  29%|████████████▌                               | 2/7 [05:38<13:30, 162.08s/it]
#  43%|██████████████████▊                         | 3/7 [07:22<09:02, 135.53s/it]
#  57%|█████████████████████████▏                  | 4/7 [08:17<05:11, 103.94s/it]
#  71%|████████████████████████████████▏            | 5/7 [09:14<02:53, 86.92s/it]
#  86%|██████████████████████████████████████▌      | 6/7 [10:48<01:29, 89.14s/it]
# 100%|█████████████████████████████████████████████| 7/7 [11:04<00:00, 65.22s/it]
#   7%|██▌                                  | 7/100 [1:17:44<17:13:04, 666.50s/it]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  14%|██████▎                                     | 1/7 [03:29<20:59, 209.90s/it]
#  29%|████████████▌                               | 2/7 [05:38<13:28, 161.79s/it]
#  43%|██████████████████▊                         | 3/7 [07:21<09:01, 135.29s/it]
#  57%|█████████████████████████▏                  | 4/7 [08:17<05:11, 103.89s/it]
#  71%|████████████████████████████████▏            | 5/7 [09:14<02:53, 86.90s/it]
#  86%|██████████████████████████████████████▌      | 6/7 [10:48<01:29, 89.29s/it]
# 100%|█████████████████████████████████████████████| 7/7 [11:04<00:00, 65.37s/it]
#   8%|██▉                                  | 8/100 [1:28:48<17:00:54, 665.81s/it]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  14%|██████▎                                     | 1/7 [03:30<21:01, 210.30s/it]
#  29%|████████████▌                               | 2/7 [05:37<13:27, 161.55s/it]
#  43%|██████████████████▊                         | 3/7 [07:22<09:01, 135.42s/it]
#  57%|█████████████████████████▏                  | 4/7 [08:17<05:11, 103.83s/it]
#  71%|████████████████████████████████▏            | 5/7 [09:14<02:53, 86.90s/it]
#  86%|██████████████████████████████████████▌      | 6/7 [10:47<01:29, 89.19s/it]
# 100%|█████████████████████████████████████████████| 7/7 [11:04<00:00, 65.29s/it]
#   9%|███▎                                 | 9/100 [1:39:52<16:48:59, 665.27s/it]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  14%|██████▎                                     | 1/7 [03:30<21:05, 210.90s/it]
#  29%|████████████▌                               | 2/7 [05:37<13:27, 161.48s/it]
#  43%|██████████████████▊                         | 3/7 [07:22<09:01, 135.41s/it]
#  57%|█████████████████████████▏                  | 4/7 [08:17<05:11, 103.85s/it]
#  71%|████████████████████████████████▏            | 5/7 [09:14<02:53, 86.76s/it]
#  86%|██████████████████████████████████████▌      | 6/7 [10:48<01:29, 89.32s/it]
# 100%|█████████████████████████████████████████████| 7/7 [11:04<00:00, 65.39s/it]
#  10%|███▌                                | 10/100 [1:50:57<16:37:33, 665.04s/it]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  14%|██████▎                                     | 1/7 [03:31<21:07, 211.22s/it]
#  29%|████████████▌                               | 2/7 [05:38<13:30, 162.08s/it]
#  43%|██████████████████▊                         | 3/7 [07:23<09:02, 135.62s/it]
#  57%|█████████████████████████▏                  | 4/7 [08:18<05:12, 104.13s/it]
#  71%|████████████████████████████████▏            | 5/7 [09:15<02:53, 86.85s/it]
#  86%|██████████████████████████████████████▌      | 6/7 [10:47<01:28, 88.80s/it]
# 100%|█████████████████████████████████████████████| 7/7 [11:03<00:00, 64.90s/it]
#  11%|███▉                                | 11/100 [2:02:00<16:25:43, 664.54s/it]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#  14%|██████▎                                     | 1/7 [03:31<21